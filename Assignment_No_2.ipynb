# %%
1.What are the two values of the Boolean data type? How do you write them?
Ans - Two Values - True and False . We require to write T and F in Capital

2. What are the three different types of Boolean operators?
Ans - Different Types - and , or and not 

3. Make a list of each Boolean operator's truth tables (i.e. every possible combination of Boolean values for the 
operator and what it evaluate ).
Ans - and Combination :
    True and True --- True
    True and False -- False
    False and True --- False
    False and False -- False
    or Combination :
    True or True --- True
    True or False -- True
    False or True --- True
    False or False -- False
    not Combination:
    not will give a exactly opposite result of and , or
    not(True and True) --- False
    not(True and False) -- True
    not(False and True) --- True
    not(False and False) -- True
    not(True or True) --- False
    not(True or False) -- False
    not(False or True) --- False
    not(False or False) -- True
    
4. What are the values of the following expressions?
Ans -(5 > 4) and (3 == 5) --- False
    not (5 > 4) --- False
    (5 > 4) or (3 == 5) --- True
    not ((5 > 4) or (3 == 5)) -- False 
    (True and True) and (True == False) --- False 
    (not False) or (not True) --- True


5. What are the six comparison operators?
Ans. Equal to (==)
     Not Equal to (!=)
     Grater than (>)
     less than (<)
     Grater than equal to (>=)
     Less than equal to (<=)
        

6. How do you tell the difference between the equal to and assignment operators?Describe a condition and when you would use one.
Ans . Assignement operator used to assign any value to variable while equal to operator used to check condition.
eg. a=10 -- here we are assigning value 10 to variable a 
    a==10 -- here we are cheacking for is a have value 10 or not 
    
    
7. Identify the three blocks in this code:
spam = 0
if spam == 10:
print('eggs')
if spam > 5:
print('bacon')
else:
print('ham')
print('spam')
print('spam')

Ans. 'ham' , 'spam' , 'spam' -- is the output for this code


8. Write code that prints Hello if 1 is stored in spam, prints Howdy if 2 is stored in spam, and prints Greetings! 
if anything else is stored in spam.

Ans - spam = int(input('Please enter value'))
      if spam ==1:
        print("Hello")
      elif spam ==2:
        print("Howdy")
      else:
        print("Greetings!")


9.If your programme is stuck in an endless loop, what keys you’ll press?
Ans- Go to the Kernel and then click on restart.


10. How can you tell the difference between break and continue?
Ans - Break -- break directly break the loop and come outside. While continue will again go to start at loop and start working.

11. In a for loop, what is the difference between range(10), range(0, 10), and range(0, 10, 1)?
Ans - There is no any difference between range(10), range(0, 10), and range(0, 10, 1)

12. Write a short program that prints the numbers 1 to 10 using a for loop. Then write an equivalent program that 
prints the numbers 1 to 10 using a while loop.
Ans - for i in range(1,11):
            print(i)
        
     a=1
     while a <=10:
            print(a)
            a=a+1
             
13. If you had a function named bacon() inside a module named spam, how would you call it after importing spam?
Ans -- import spam
       spam.bacon()
