# %%
1. What exactly is []?
Ans - This is a square bracket and we use this for list assignment and getting index of any item . 

2. In a list of values stored in a variable called spam, how would you assign the value 'hello' as the third value? 
(Assume [2, 4, 6, 8, 10] are in spam.)

Ans - spam[2]='hello'

Let's pretend the spam includes the list ['a', 'b', 'c', 'd'] for the next three queries.
3. What is the value of spam[int(int('3' * 2) / 11)]?
Ans- 'd' 

4. What is the value of spam[-1]?
Ans - 'd'

5. What is the value of spam[:2]?
Ans - ['a','b']

Let's pretend bacon has the list [3.14, 'cat,' 11, 'cat,' True] for the next three questions.
6. What is the value of bacon.index('cat')?
Ans - 1
7. How does bacon.append(99) change the look of the list value in bacon?
Ans - It append 99 at the last position and list will look like -- [3.14, 'cat,' 11, 'cat,' True,99]

8. How does bacon.remove('cat') change the look of the list in bacon?
Ans - It will remove the first ocurance of 'cat' and liks will look like - [3.14, 11, 'cat,' True,99]

9. What are the list concatenation and list replication operators?
Ans - IN list concatenation we will add the new list in existing list from its last element.
e.g. l1=[1,2,3] and l2=[3,5,6] then l1 +l2 = [1, 2, 3, 3, 5, 6] 
In list replication we can replicate same list for as per our requirements.
e.g.  l1=[1,2,3] , l1*2 = [1, 2, 3, 1, 2, 3]

10. What is difference between the list methods append() and insert()?
Ans - In list.append() we add new element as the last position while in list.insert() we can add element at any index 
position as per our requirement.

11. What are the two methods for removing items from a list?
Ans - list.pop() and list.remove()

12. Describe how list values and string values are identical.
Ans - Both list and string are iterable and we can perform indexing and slicing operation with both.

13. What's the difference between tuples and lists?
Ans- List are mutable while tuples are immutable. We use [] for list assignment while we use  () for tuple.

14. How do you type a tuple value that only contains the integer 42?
Ans - t1=(42,) 

15. How do you get a list value's tuple form? How do you get a tuple value's list form?
Ans - convert list into tuples -- tuple(list1) and convert tuple into list -- list(tuple1)

16. Variables that "contain" list values are not necessarily lists themselves. Instead, what do they contain?
Ans - They contain  references to list values.

17. How do you distinguish between copy.copy() and copy.deepcopy()?
Ans - copy() create reference to original object. If you change copied object - you change the original object.
deepcopy() creates new object and does real copying of original object to new one. Changing new deepcopied object 
doesn't affect original object.
