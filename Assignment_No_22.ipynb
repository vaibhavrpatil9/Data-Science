# %%
1. What is the result of the code, and explain?


>>> X = 'iNeuron'
>>> def func():
print(X)


>>> func()
Ans - Result is 'iNeuron' because we define the function and we print it inside the function


2. What is the result of the code, and explain?


>>> X = 'iNeuron'
>>> def func():
X = 'NI!'

>>> func()
>>> print(X)
Ans - func() -- no any output  and print(x)-- 'iNeuron' becase we reassign  x in function but we didnt print or call it 
and print(x) will will give 'iNeuron' becuase it is global varibale.

3. What does this code print, and why?


>>> X = 'iNeuron'
>>> def func():
X = 'NI'
print(X)


>>> func()
>>> print(X)

Ans - func()-- "NI!" and print(X)-- 'iNeuron' because we reassign x in functiona and then print it and for print(X) outside we 
we will get 'iNeuron' because it is global variable.


4. What output does this code produce? Why?


>>> X = 'iNeuron'
>>> def func():
global X
X = 'NI'


>>> func()
>>> print(X)

Ans - for both func() and print(X) we will get 'NI' as a output becasue it make X as a global inside the function and then
reassign new value to it.


5. What about this code—what’s the output, and why?


>>> X = 'iNeuron'
>>> def func():
X = 'NI'
def nested():
print(X)
nested()


>>> func()
>>> X
Ans - func() -- 'NI' and x -- 'iNeuron' as here we use nasted function and did x is global and we did not use 
global inside the function.

6. How about this code: what is its output in Python 3, and explain?


>>> def func():
X = 'NI'
def nested():
nonlocal X
X = 'Spam'
nested()
print(X)


>>> func()

Ans - func() -- 'Spam' as we use reassign X inside the nested() function and make it nonlocal.
